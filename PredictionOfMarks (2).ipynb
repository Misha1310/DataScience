# %%
#importing all the libraries required
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#reading data from remote link
url="https://bit.ly/w-data"
s_data=pd.read_csv(url)
print("Data imported successfully")

s_data.head(10) #if we do not pass any parameter the by default it will print 5 students data
# Out:
# Data imported successfully
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20
# 6    9.2      88
# 7    5.5      60
# 8    8.3      81
# 9    2.7      25

# %%
#plotting the distribution of scores
s_data.plot(x='Hours',y='Scores',style='*')
plt.title('Hours Vs Percentage')
plt.xlabel=('Hours Studied')
plt.ylabel=('Percentage Score')
plt.show()

# %%
#from the above graph ,we can clearly see that there is a positive linear relation between the number of hours studied and percentage score

# %%
#Preparation Of Data
#The next step is to divide the data into "attributes" (Inputs) and "labels" (Ouputs)
x=s_data.iloc[:,:-1].values
y=s_data.iloc[:,1].values

# %%
x,y
# Out:
# (array([[2.5],
#         [5.1],
#         [3.2],
#         [8.5],
#         [3.5],
#         [1.5],
#         [9.2],
#         [5.5],
#         [8.3],
#         [2.7],
#         [7.7],
#         [5.9],
#         [4.5],
#         [3.3],
#         [1.1],
#         [8.9],
#         [2.5],
#         [1.9],
#         [6.1],
#         [7.4],
#         [2.7],
#         [4.8],
#         [3.8],
#         [6.9],
#         [7.8]]),
#  array([21, 47, 27, 75, 30, 20, 88, 60, 81, 25, 85, 62, 41, 42, 17, 95, 30,
#         24, 67, 69, 30, 54, 35, 76, 86]))

# %%
#second method to prepare data
x=s_data[['Hours']].values
y=s_data[['Scores']].values

# %%
x,y
# Out:
# (array([[2.5],
#         [5.1],
#         [3.2],
#         [8.5],
#         [3.5],
#         [1.5],
#         [9.2],
#         [5.5],
#         [8.3],
#         [2.7],
#         [7.7],
#         [5.9],
#         [4.5],
#         [3.3],
#         [1.1],
#         [8.9],
#         [2.5],
#         [1.9],
#         [6.1],
#         [7.4],
#         [2.7],
#         [4.8],
#         [3.8],
#         [6.9],
#         [7.8]]), array([[21],
#         [47],
#         [27],
#         [75],
#         [30],
#         [20],
#         [88],
#         [60],
#         [81],
#         [25],
#         [85],
#         [62],
#         [41],
#         [42],
#         [17],
#         [95],
#         [30],
#         [24],
#         [67],
#         [69],
#         [30],
#         [54],
#         [35],
#         [76],
#         [86]]))

# %%
#splitting the data in train set and test set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
#Training the algorithm
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
print("Training Complete")
# Out:
# Training Complete

# %%
#plotting the regression line
line=regressor.coef_*x+regressor.intercept_

#plotting for the test data
plt.scatter(x,y)
plt.plot(x,line)
plt.title("Comparison")
plt.show()

# %%
#making predictions
print(x_test)
y_pred=regressor.predict(x_test)
# Out:
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]]

# %%
#Comparing actual vs predicted
df = pd.DataFrame({'Actual':[y_test],'Predicted':[y_pred]})
df
# Out:
#                            Actual                                          Predicted
# 0  [[20], [27], [69], [30], [62]]  [[16.884144762398023], [33.732260779489835], [...

# %%
score_pred=np.array([7])
score_pred=score_pred.reshape(-1,1)
predict=regressor.predict(score_pred)
print("No of hours={}".format(7))
print("predicted score={}".format(predict[0]))
# Out:
# No of hours=7
# predicted score=[71.39275541]

# %%
#Evaluating the model
from sklearn import metrics
print('Mean Absolute error:',metrics.mean_absolute_error(y_test,y_pred))
# Out:
# Mean Absolute error: 4.183859899002982
